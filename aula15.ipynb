# %%
# %pip install sklearn
# Out:
# ...
#
# ...
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# ...
#   Created wheel for sklearn: filename=sklearn-0.0.post7-py3-none-any.whl size=2970 sha256=d844293b3c2955d5754181854375ad213f252783e1ec803f9f5b0d02e8680103
#   Stored in directory: c:\users\franc\appdata\local\pip\cache\wheels\08\17\db\46486df299847133f69165c029fe388fac45781eb5d436c569
# Successfully built sklearn
# ...
# [notice] A new release of pip is available: 23.1.2 -> 23.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd

# %%
df = pd.read_csv('realtor-data.csv')

# %%
df
# Out:
#          status  bed  bath  acre_lot        city          state  zip_code  \
# 0      for_sale  3.0   2.0      0.12    Adjuntas    Puerto Rico     601.0
# 1      for_sale  4.0   2.0      0.08    Adjuntas    Puerto Rico     601.0
# 2      for_sale  2.0   1.0      0.15  Juana Diaz    Puerto Rico     795.0
# 3      for_sale  4.0   2.0      0.10       Ponce    Puerto Rico     731.0
# 4      for_sale  6.0   2.0      0.05    Mayaguez    Puerto Rico     680.0
# ...         ...  ...   ...       ...         ...            ...       ...
# 99995  for_sale  3.0   3.0       NaN      Hudson  Massachusetts    1749.0
# 99996  for_sale  2.0   1.0      0.34      Auburn  Massachusetts    1501.0
# 99997  for_sale  3.0   2.0      1.01  Shrewsbury  Massachusetts    1545.0
# 99998  for_sale  3.0   2.0      0.12   Worcester  Massachusetts    1604.0
# 99999  for_sale  3.0   3.0     21.67     Grafton  Massachusetts    1536.0
#
#        house_size prev_sold_date     price
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 10 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   status          100000 non-null  object
#  1   bed             75050 non-null   float64
#  2   bath            75112 non-null   float64
#  3   acre_lot        85987 non-null   float64
#  4   city            99948 non-null   object
#  5   state           100000 non-null  object
#  6   zip_code        99805 non-null   float64
#  7   house_size      75082 non-null   float64
#  8   prev_sold_date  28745 non-null   object
#  9   price           100000 non-null  float64
# dtypes: float64(6), object(4)
# memory usage: 7.6+ MB

# %%
df['missing_house_size'] = np.where(df['house_size'].isnull(),1,0)

# %%
import numpy as np

# %%
df
# Out:
#          status  bed  bath  acre_lot        city          state  zip_code  \
# 0      for_sale  3.0   2.0      0.12    Adjuntas    Puerto Rico     601.0
# 1      for_sale  4.0   2.0      0.08    Adjuntas    Puerto Rico     601.0
# 2      for_sale  2.0   1.0      0.15  Juana Diaz    Puerto Rico     795.0
# 3      for_sale  4.0   2.0      0.10       Ponce    Puerto Rico     731.0
# 4      for_sale  6.0   2.0      0.05    Mayaguez    Puerto Rico     680.0
# ...         ...  ...   ...       ...         ...            ...       ...
# 99995  for_sale  3.0   3.0       NaN      Hudson  Massachusetts    1749.0
# 99996  for_sale  2.0   1.0      0.34      Auburn  Massachusetts    1501.0
# 99997  for_sale  3.0   2.0      1.01  Shrewsbury  Massachusetts    1545.0
# 99998  for_sale  3.0   2.0      0.12   Worcester  Massachusetts    1604.0
# 99999  for_sale  3.0   3.0     21.67     Grafton  Massachusetts    1536.0
#
#        house_size prev_sold_date     price  missing_house_size
# ...

# %%
df.groupby(['state','city']).agg({'house_size': ['max','min','mean']
                                 ,'missing_house_size': 'mean'}).reset_index()
# Out:
#               state          city house_size                       \
#                                          max     min         mean
# 0       Connecticut       Andover     3307.0   996.0  1626.352941
# 1       Connecticut       Ashford     2842.0  1008.0  1622.903846
# 2       Connecticut          Avon     9700.0   895.0  3078.239669
# 3       Connecticut   Barkhamsted     3482.0  1434.0  2396.872340
# 4       Connecticut        Berlin     4100.0   856.0  1639.291667
# ..              ...           ...        ...     ...          ...
# 577  Virgin Islands  Frederiksted    49658.0   860.0  6656.175439
# 578  Virgin Islands     Kingshill     2700.0  1200.0  1617.575758
# 579  Virgin Islands    Saint John    30378.0   580.0  5296.250000
# 580  Virgin Islands  Saint Thomas    10695.0   235.0  3483.603448
# 581        Virginia  Chincoteague        NaN     NaN          NaN
#
#     missing_house_size
#                   mean
# 0             0.291667
# 1             0.223881
# ...
