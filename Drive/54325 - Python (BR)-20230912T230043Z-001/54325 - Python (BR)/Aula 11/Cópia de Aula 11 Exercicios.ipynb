# %% [markdown]
# # Visualização de Dados
# ## Exercicios em Sala
# Crie visualizações usando o arquivo fastfood.xlsx, como:
#  - Gráfico de barras
#  - Histograma
#  - Distribuição
#  - Dispersão

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
fastfood = pd.read_excel("fastfood.xlsx")
fastfood.head(3)
# Out:
#   restaurant                              item  calories  cal_fat  total_fat  \
# 0  Mcdonalds  Artisan Grilled Chicken Sandwich       380       60          7
# 1  Mcdonalds    Single Bacon Smokehouse Burger       840      410         45
# 2  Mcdonalds    Double Bacon Smokehouse Burger      1130      600         67
#
#   sat_fat            trans_fat  cholesterol  sodium  total_carb  fiber  sugar  \
# 0       2                    0           95    1110          44    3.0     11
# 1      17  2023-05-01 00:00:00          130    1580          62    2.0     18
# 2      27                    3          220    1920          63    3.0     18
#
#    protein  vit_a  vit_c  calcium  salad
# 0     37.0    4.0   20.0     20.0  Other
# 1     46.0    6.0   20.0     20.0  Other
# 2     70.0   10.0   20.0     50.0  Other

# %%
fastfood_agg = fastfood.groupby('restaurant').mean(numeric_only=True).reset_index()

plt.bar(fastfood_agg['restaurant'], fastfood_agg['calories'], color='gray')
plt.xticks(rotation=45)

plt.title("Media de Calorias por Restaurante")
plt.xlabel("Restaurante")
plt.ylabel("Media de Calorias")

plt.show()

# %%
plt.hist(fastfood['calories'], bins=8)

plt.title("Histograma Calorias")


plt.show()

# %%
# Plotar histograma e distribuição
sns.displot(fastfood['calories'], kde=True )
plt.show()

# %%
sns.scatterplot(x='calories', y='sugar', size = 'protein',data=fastfood, alpha=0.7)
plt.show()
